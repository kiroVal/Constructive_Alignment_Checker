# %%
# %pip install python-docx
# Out:
# Requirement already satisfied: python-docx in /usr/local/lib/python3.11/dist-packages (1.2.0)
# Requirement already satisfied: lxml>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from python-docx) (5.4.0)
# Requirement already satisfied: typing_extensions>=4.9.0 in /usr/local/lib/python3.11/dist-packages (from python-docx) (4.14.1)

# %%
from docx import Document
import pandas as pd
import glob
import os
import re

# === SETTINGS ===
input_folder = "/content/docx_folder"   # source folder with Word files
output_folder = "/content/csv_outputs" # destination folder for CSVs
# Define canonical headers and their possible variations in source documents
header_mapping = {
    "Learning Outcomes": ["Learning Outcomes", "Learning Outcome", "Learning\nOutcomes"],
    "Deliverables Outcomes": ["Deliverables Outcomes", "Deliverables/Outcomes", "Deliverables", "Deliverables/\nOutcomes", "Deliverables\n/ Outcomes"],
    "Assessments": ["Assessments", "Assessment"]
}

os.makedirs(output_folder, exist_ok=True)

# === FUNCTIONS ===
def normalize_header(text):
    """
    Normalize header text: lowercase, remove spaces, slashes, punctuation.
    E.g., 'Deliverables/ Outcomes' -> 'deliverablesoutcomes'
    """
    return re.sub(r'[^a-z0-9]', '', text.lower())

# Normalize header mapping for easier lookup
normalized_header_mapping = {
    normalize_header(k): [normalize_header(v) for v in values]
    for k, values in header_mapping.items()
}

# Get a set of all possible normalized variations we are looking for
all_normalized_variations = set()
for variations in normalized_header_mapping.values():
    all_normalized_variations.update(variations)


# === MAIN LOOP ===
for file in glob.glob(os.path.join(input_folder, "*.docx")):
    doc = Document(file)
    file_found_relevant_table = False # Track if any relevant table was found in the file


    for i, table in enumerate(doc.tables):
        # Check if the table has at least one row (the header row)
        if len(table.rows) > 0:
            headers = [cell.text.strip() for cell in table.rows[0].cells]
            normalized_headers = [normalize_header(h) for h in headers]

            # Check if a significant number of wanted headers are present as substrings in the first row headers
            matched_canonical_headers = []
            col_indices = []
            final_headers = []

            for canonical_header, possible_variations in header_mapping.items():
                normalized_canonical_header = normalize_header(canonical_header)
                found_variation_index = -1
                # Check if any of the normalized variations are substrings of the normalized headers in the table
                for variation in possible_variations:
                    normalized_variation = normalize_header(variation)
                    for j, normalized_table_header in enumerate(normalized_headers):
                        if normalized_variation in normalized_table_header:
                            found_variation_index = j # Found a match at this column index
                            break # Found a match for this canonical header, move to the next canonical header
                    if found_variation_index != -1:
                        break # Found a match for this canonical header variation

                if found_variation_index != -1:
                    col_indices.append(found_variation_index)
                    final_headers.append(canonical_header) # Use the canonical header in the final DataFrame
                    matched_canonical_headers.append(canonical_header)


            # If at least 2 canonical headers were matched as substrings, consider this a relevant table
            if len(matched_canonical_headers) >= 2:
                 print(f"\nProcessing file: {os.path.basename(file)}") # Print file name only when a relevant table is found
                 print(f"  Found potentially relevant Table {i+1}.")
                 print(f"    Headers in Table {i+1} (first row): {headers}")
                 print(f"    Matched canonical headers: {matched_canonical_headers}")


                 # Extract data if wanted columns are found (should be true based on the >=2 check)
                 if col_indices:
                     data = []
                     for row in table.rows[1:]: # Skip header row
                         row_data = []
                         for j in col_indices:
                             if j < len(row.cells): # Check if cell index is valid
                                 row_data.append(row.cells[j].text.strip())
                             else:
                                 row_data.append("") # Add empty string if cell is missing
                         data.append(row_data)

                     # Create DataFrame and save to CSV
                     df = pd.DataFrame(data, columns=final_headers)
                     output_filename = os.path.join(output_folder, os.path.splitext(os.path.basename(file))[0] + ".csv")
                     df.to_csv(output_filename, index=False)
                     print(f"    Successfully extracted data from Table {i+1} to {os.path.basename(output_filename)}")
                     file_found_relevant_table = True
                     # Don't break, continue checking other tables in the same file in case there are multiple relevant tables


    if not file_found_relevant_table:
        print(f"\nNo relevant table with at least 2 of the main headers {list(header_mapping.keys())} found in {os.path.basename(file)}")


print("\nProcessing complete.")
# Out:
# Processing file: CRISKMA Syllabus AY 2024 - 2025.docx
#   Found potentially relevant Table 5.
#     Headers in Table 5 (first row): ['Week', 'Topics', 'Learning Activities', 'Learning Outcomes', 'CO\nAligned to', 'Instructional Materials', 'Deliverables/\nOutcomes', 'Assessment']
#     Matched canonical headers: ['Learning Outcomes', 'Deliverables Outcomes', 'Assessments']
#     Successfully extracted data from Table 5 to CRISKMA Syllabus AY 2024 - 2025.csv
#
# Processing file: INPROLA Syllabus 2ndTerm_2024ver3.0.docx
#   Found potentially relevant Table 10.
#     Headers in Table 10 (first row): ['Week', 'Topics', 'Learning Activities', 'Learning Outcomes', 'CO aligned to', 'Instructional Materials', 'Assessment']
#     Matched canonical headers: ['Learning Outcomes', 'Assessments']
#     Successfully extracted data from Table 10 to INPROLA Syllabus 2ndTerm_2024ver3.0.csv
#
# Processing file: QUALITY_SYLLABUS_AY_2023_2024 for IT.docx
#   Found potentially relevant Table 5.
#     Headers in Table 5 (first row): ['Week', 'Topics', 'Learning Activities', 'Learning Outcomes', 'Instructional Materials', 'Deliverables/\nOutcomes', 'Assessment']
#     Matched canonical headers: ['Learning Outcomes', 'Deliverables Outcomes', 'Assessments']
#     Successfully extracted data from Table 5 to QUALITY_SYLLABUS_AY_2023_2024 for IT.csv
#
# Processing file: DASTRUC_Syllabus T1 AY 2024-2025 Revise version.docx
#   Found potentially relevant Table 9.
#     Headers in Table 9 (first row): ['Week', 'Topics', 'Learning Activities', 'Learning Outcomes', 'Instructional Materials', 'Deliverables / Outcomes', 'Assessment']
#     Matched canonical headers: ['Learning Outcomes', 'Deliverables Outcomes', 'Assessments']
#     Successfully extracted data from Table 9 to DASTRUC_Syllabus T1 AY 2024-2025 Revise version.csv
#
# Processing file: INTSDEV_Syllabus_2023-2024.docx
#   Found potentially relevant Table 7.
#     Headers in Table 7 (first row): ['Week', 'Topics', 'Learning Activities', 'Learning Outcomes', 'Instructional Materials', 'Deliverables/\nOutcomes', 'Assessment']
#     Matched canonical headers: ['Learning Outcomes', 'Deliverables Outcomes', 'Assessments']
#     Successfully extracted data from Table 7 to INTSDEV_Syllabus_2023-2024.csv
#
# Processing file: AUTOMAT_SYLLABUS_2ndTerm_2024_ver3.0.docx
#   Found potentially relevant Table 7.
#     Headers in Table 7 (first row): ['Week', 'Topics', 'Learning Activities', 'Learning Outcomes', 'CO aligned to:', 'Instructional Materials', 'Deliverables/\nOutcomes', 'Assessment']
#     Matched canonical headers: ['Learning Outcomes', 'Deliverables Outcomes', 'Assessments']
#     Successfully extracted data from Table 7 to AUTOMAT_SYLLABUS_2ndTerm_2024_ver3.0.csv
#
# Processing file: CSPROJ2 Course Syllabus AY2024-2025 (KRC)v.03.docx
#   Found potentially relevant Table 15.
#     Headers in Table 15 (first row): ['Week\n#', 'Topics', 'Learning\nActivities', 'Learning\nOutcomes', 'Instructional\nMaterials*', 'Deliverables\n/ Outcomes', 'Assessment']
#     Matched canonical headers: ['Learning Outcomes', 'Deliverables Outcomes', 'Assessments']
#     Successfully extracted data from Table 15 to CSPROJ2 Course Syllabus AY2024-2025 (KRC)v.03.csv
#
# Processing file: MNSYSIT Course Syllabus AY 2024-2025.docx
#   Found potentially relevant Table 9.
#     Headers in Table 9 (first row): ['Week', 'Topics', 'Learning Activities', 'Learning Outcomes (LO) / Learner and Learning Outcomes (LLO)', 'CO / CLO Aligned to', 'Instructional Materials', 'Deliverables/ Outcomes', 'Assessment']
#     Matched canonical headers: ['Learning Outcomes', 'Deliverables Outcomes', 'Assessments']
#     Successfully extracted data from Table 9 to MNSYSIT Course Syllabus AY 2024-2025.csv
#
# Processing file: COMSEC2_Syllabus_2024.docx
#   Found potentially relevant Table 7.
#     Headers in Table 7 (first row): ['Week', 'Topics', 'Learning Activities', 'Learning Outcomes', 'Instructional Materials', 'Deliverables/\nOutcomes', 'Assessment']
#     Matched canonical headers: ['Learning Outcomes', 'Deliverables Outcomes', 'Assessments']
#     Successfully extracted data from Table 7 to COMSEC2_Syllabus_2024.csv
#
# Processing file: CLDSRV2_Syllabus 2023_2024.docx
#   Found potentially relevant Table 5.
#     Headers in Table 5 (first row): ['Week', 'Topics', 'Learning Activities', 'Learning Outcomes', 'Instructional Materials', 'Deliverables/ Outcomes', 'Assessment']
#     Matched canonical headers: ['Learning Outcomes', 'Deliverables Outcomes', 'Assessments']
#     Successfully extracted data from Table 5 to CLDSRV2_Syllabus 2023_2024.csv
#
# Processing file: COMSEC3_Syllabus_2024 - 2025.docx
#   Found potentially relevant Table 7.
#     Headers in Table 7 (first row): ['Week', 'Topics', 'Learning\xa0Activities', 'Learning Outcomes', 'CO \nAligned to', 'Instructional Materials', 'Deliverables/\xa0 Outcomes', 'Assessment']
#     Matched canonical headers: ['Learning Outcomes', 'Deliverables Outcomes', 'Assessments']
#     Successfully extracted data from Table 7 to COMSEC3_Syllabus_2024 - 2025.csv
#
# Processing file: DATAMA2_SYLLABUS_1st_Term_2024_version.docx
#   Found potentially relevant Table 6.
#     Headers in Table 6 (first row): ['Week', 'Topics', 'Learning Activities', 'Learning Outcomes', 'Instructional Materials', 'Deliverables/\nOutcomes', 'Assessment']
#     Matched canonical headers: ['Learning Outcomes', 'Deliverables Outcomes', 'Assessments']
#     Successfully extracted data from Table 6 to DATAMA2_SYLLABUS_1st_Term_2024_version.csv
#
# Processing file: Course Syllabus PHYSICS1 Natural Physics 1 for IT.docx
#   Found potentially relevant Table 6.
#     Headers in Table 6 (first row): ['Week', 'Topics', 'Learning Activities', 'Learning Outcomes (LO) / Learner and Learning Outcomes (LLO)', 'CO Aligned to', 'Instructional Materials', 'Deliverables/ Outcomes', 'Assessment']
#     Matched canonical headers: ['Learning Outcomes', 'Deliverables Outcomes', 'Assessments']
#     Successfully extracted data from Table 6 to Course Syllabus PHYSICS1 Natural Physics 1 for IT.csv
#
# Processing file: QUALITY_SYLLABUS_2023 for CS.docx
#   Found potentially relevant Table 5.
#     Headers in Table 5 (first row): ['Week', 'Topics', 'Learning Activities', 'Learning Outcomes', 'Instructional Materials', 'Deliverables/\nOutcomes', 'Assessment']
#     Matched canonical headers: ['Learning Outcomes', 'Deliverables Outcomes', 'Assessments']
#     Successfully extracted data from Table 5 to QUALITY_SYLLABUS_2023 for CS.csv
#
# Processing file: DATAMA1_SYLLABUS_Ver3.0_2023.docx
#   Found potentially relevant Table 5.
#     Headers in Table 5 (first row): ['Week', 'Topics', 'Learning Activities', 'Learning Outcomes', 'Instructional Materials', 'Deliverables/\nOutcomes', 'Assessment']
#     Matched canonical headers: ['Learning Outcomes', 'Deliverables Outcomes', 'Assessments']
#     Successfully extracted data from Table 5 to DATAMA1_SYLLABUS_Ver3.0_2023.csv
#
# Processing file: CLDSRV2_Syllabus_2024.docx
#   Found potentially relevant Table 7.
#     Headers in Table 7 (first row): ['Week', 'Topics', 'Learning Activities', 'Learning Outcomes', 'Instructional Materials', 'Deliverables/ Outcomes', 'Assessment']
#     Matched canonical headers: ['Learning Outcomes', 'Deliverables Outcomes', 'Assessments']
#     Successfully extracted data from Table 7 to CLDSRV2_Syllabus_2024.csv
#
# Processing file: MNTSDEV-SNTSDEV-INTSDEV Course Syllabus AY 2024 - 2025 v2.docx
#   Found potentially relevant Table 9.
#     Headers in Table 9 (first row): ['Week', 'Topics', 'Learning Activities', 'Learning Outcomes', 'CO \nAligned to', 'Instructional Materials', 'Deliverables/\nOutcomes', 'Assessment']
#     Matched canonical headers: ['Learning Outcomes', 'Deliverables Outcomes', 'Assessments']
#     Successfully extracted data from Table 9 to MNTSDEV-SNTSDEV-INTSDEV Course Syllabus AY 2024 - 2025 v2.csv
#
# Processing file: NETDESM_2024.docx
#   Found potentially relevant Table 6.
#     Headers in Table 6 (first row): ['Week', 'Topics', 'Learning Activities', 'Learning Outcomes (LO) / Learner and Learning Outcomes (LLO)', 'CO\nAligned to', 'Instructional Materials', 'Deliverables/\nOutcomes', 'Assessment']
#     Matched canonical headers: ['Learning Outcomes', 'Deliverables Outcomes', 'Assessments']
#     Successfully extracted data from Table 6 to NETDESM_2024.csv
#
# Processing file: OPESYST_SYLLABUS_AY2024-2025.docx
#   Found potentially relevant Table 9.
#     Headers in Table 9 (first row): ['Week', 'Topics', 'Learning Activities', 'Learning Outcomes', 'Instructional Materials', 'Assessment']
#     Matched canonical headers: ['Learning Outcomes', 'Assessments']
#     Successfully extracted data from Table 9 to OPESYST_SYLLABUS_AY2024-2025.csv
#
# Processing file: PROGCON_SYLLABUS_2024_1stTerm_version.docx
#   Found potentially relevant Table 7.
#     Headers in Table 7 (first row): ['Week', 'Topics', 'Learning Activities', 'Learning Outcomes', 'Instructional Materials', 'Deliverables/\xa0\nOutcomes', 'Assessment']
#     Matched canonical headers: ['Learning Outcomes', 'Deliverables Outcomes', 'Assessments']
#     Successfully extracted data from Table 7 to PROGCON_SYLLABUS_2024_1stTerm_version.csv
#
# Processing file: PROJMAN AY 2023_2024 Syllabus.docx
#   Found potentially relevant Table 3.
#     Headers in Table 3 (first row): ['Week', 'Topics', 'Learning Activities', 'Learning Outcomes', 'Instructional Materials', 'Deliverables/ Outcomes', 'Assessment Task']
#     Matched canonical headers: ['Learning Outcomes', 'Deliverables Outcomes', 'Assessments']
#     Successfully extracted data from Table 3 to PROJMAN AY 2023_2024 Syllabus.csv
#
# Processing file: DESALGO_Syllabus_2024.docx
#   Found potentially relevant Table 6.
#     Headers in Table 6 (first row): ['Week', 'Topics', 'Learning Activities', 'Learning Outcomes', 'Instructional Materials', 'Deliverables/\nOutcomes', 'Assessment']
#     Matched canonical headers: ['Learning Outcomes', 'Deliverables Outcomes', 'Assessments']
#     Successfully extracted data from Table 6 to DESALGO_Syllabus_2024.csv
#
# Processing file: MNSYSIT Salesforce_AY 2023-2024 v2.docx
#   Found potentially relevant Table 5.
#     Headers in Table 5 (first row): ['Week', 'Topics', 'Learning Activities', 'Learning Outcomes', 'Instructional Materials', 'Deliverables/ Outcomes', 'Assessment']
#     Matched canonical headers: ['Learning Outcomes', 'Deliverables Outcomes', 'Assessments']
#     Successfully extracted data from Table 5 to MNSYSIT Salesforce_AY 2023-2024 v2.csv
#
# Processing file: MNSYSIT Salesforce_T1 AY 2024-2025 for upload.docx
#   Found potentially relevant Table 9.
#     Headers in Table 9 (first row): ['Week', 'Topics', 'Learning Activities', 'Learning Outcomes', 'Instructional Materials', 'Deliverables/ Outcomes', 'Assessment', 'Mode']
#     Matched canonical headers: ['Learning Outcomes', 'Deliverables Outcomes', 'Assessments']
#     Successfully extracted data from Table 9 to MNSYSIT Salesforce_T1 AY 2024-2025 for upload.csv
#
# Processing file: ICTSRV1_Syllabus_2024.docx
#   Found potentially relevant Table 6.
#     Headers in Table 6 (first row): ['Week', 'Topics', 'Learning Activities', 'Learning Outcomes', 'Instructional Materials', 'Deliverables/\nOutcomes', 'Assessment']
#     Matched canonical headers: ['Learning Outcomes', 'Deliverables Outcomes', 'Assessments']
#     Successfully extracted data from Table 6 to ICTSRV1_Syllabus_2024.csv
#
# Processing file: INPROLA Syllabus Revision T1 A.Y. 2023 Revise Oct 2023.docx
#   Found potentially relevant Table 7.
#     Headers in Table 7 (first row): ['Week', 'Topics', 'Learning Activities', 'Learning Outcomes', 'Instructional Materials', 'Assessment']
#     Matched canonical headers: ['Learning Outcomes', 'Assessments']
#     Successfully extracted data from Table 7 to INPROLA Syllabus Revision T1 A.Y. 2023 Revise Oct 2023.csv
#
# Processing file: MOBPROG Course Syllabus 1T 2022 - Revise Oct 2023.docx
#   Found potentially relevant Table 2.
#     Headers in Table 2 (first row): ['W\ne\ne\nk', 'Topics', 'Learning Activities', 'Learning Outcomes\n(At the end of the session, students are expected to:)', 'Instructional Materials', 'Deliverables/\nOutcomes', 'Assessment']
#     Matched canonical headers: ['Learning Outcomes', 'Deliverables Outcomes', 'Assessments']
#     Successfully extracted data from Table 2 to MOBPROG Course Syllabus 1T 2022 - Revise Oct 2023.csv
#
# Processing file: INFOSEC_Syllabus_2023.docx
#   Found potentially relevant Table 8.
#     Headers in Table 8 (first row): ['Week', 'Topics', 'Learning Activities', 'Learning Outcomes', 'Instructional Materials', 'Deliverables/\nOutcomes', 'Assessment']
#     Matched canonical headers: ['Learning Outcomes', 'Deliverables Outcomes', 'Assessments']
#     Successfully extracted data from Table 8 to INFOSEC_Syllabus_2023.csv
#
# Processing file: CLDCOMP_Syllabus 2023-2024.docx
#   Found potentially relevant Table 5.
#     Headers in Table 5 (first row): ['Week', 'Topics', 'Learning Activities', 'Learning Outcomes', 'Instructional Materials', 'Deliverables/\nOutcomes', 'Assessment']
#     Matched canonical headers: ['Learning Outcomes', 'Deliverables Outcomes', 'Assessments']
#     Successfully extracted data from Table 5 to CLDCOMP_Syllabus 2023-2024.csv
#
# Processing file: THESIS2 2023 Syllabus  T1 AY 2024 2025.docx
#   Found potentially relevant Table 7.
#     Headers in Table 7 (first row): ['Week', 'Topics', 'Learning Activities', 'Learning Activities', 'Learning Outcomes', 'Instructional Materials', 'Deliverables/ Outcomes', 'Assessment']
#     Matched canonical headers: ['Learning Outcomes', 'Deliverables Outcomes', 'Assessments']
#     Successfully extracted data from Table 7 to THESIS2 2023 Syllabus  T1 AY 2024 2025.csv
#
# Processing file: MCSPROJ Course Syllabus AY2024-2025 for IT.docx
#   Found potentially relevant Table 10.
#     Headers in Table 10 (first row): ['Week #', 'Topics', 'Learning Activities', 'Learning Outcomes (LO) / Learner and Learning Outcomes (LLO)', 'CO / CLO \nAligned to', 'Instructional Materials*', 'Deliverables\n/ Outcomes/Rubrics', 'Deliverables\n/ Outcomes/Rubrics', 'Deliverables\n/ Outcomes/Rubrics', 'Assessment']
#     Matched canonical headers: ['Learning Outcomes', 'Deliverables Outcomes', 'Assessments']
#     Successfully extracted data from Table 10 to MCSPROJ Course Syllabus AY2024-2025 for IT.csv
#
# Processing file: SSYADD1-MSYADD1_Syllabus_2023.docx
#   Found potentially relevant Table 7.
#     Headers in Table 7 (first row): ['Week', 'Topics', 'Learning Activities', 'Learning Outcomes', 'Instructional Materials', 'Deliverables/\nOutcomes', 'Assessment']
#     Matched canonical headers: ['Learning Outcomes', 'Deliverables Outcomes', 'Assessments']
#     Successfully extracted data from Table 7 to SSYADD1-MSYADD1_Syllabus_2023.csv
#
# Processing file: INFOSEC_Syllabus_T1_AY_2024_2025.docx
#   Found potentially relevant Table 10.
#     Headers in Table 10 (first row): ['Week', 'Topics', 'Learning Activities', 'Learning Outcomes', 'Instructional Materials', 'Deliverables/\nOutcomes', 'Assessment']
#     Matched canonical headers: ['Learning Outcomes', 'Deliverables Outcomes', 'Assessments']
#     Successfully extracted data from Table 10 to INFOSEC_Syllabus_T1_AY_2024_2025.csv
#
# Processing file: PROGCON Syllabus Revision  T1 A.Y. 2023-2024 Revise Oct 2023.docx
#   Found potentially relevant Table 3.
#     Headers in Table 3 (first row): ['Week', 'Topics', 'Learning Activities', 'Learning Outcomes', 'Instructional Materials', 'Assessment\n/ Output']
#     Matched canonical headers: ['Learning Outcomes', 'Assessments']
#     Successfully extracted data from Table 3 to PROGCON Syllabus Revision  T1 A.Y. 2023-2024 Revise Oct 2023.csv
#
# Processing file: WEBPSEC_Syllabus_2024.docx
#   Found potentially relevant Table 5.
#     Headers in Table 5 (first row): ['Week', 'Topics', 'Learning Activities', 'Learning Outcomes', 'Instructional Materials', 'Deliverables/\nOutcomes', 'Assessment']
#     Matched canonical headers: ['Learning Outcomes', 'Deliverables Outcomes', 'Assessments']
#     Successfully extracted data from Table 5 to WEBPSEC_Syllabus_2024.csv
#
# Processing file: COMSECT_Syllabus_2024.docx
#   Found potentially relevant Table 7.
#     Headers in Table 7 (first row): ['Week', 'Topics', 'Learning Activities', 'Learning Outcomes', 'Instructional Materials', 'Deliverables/\nOutcomes', 'Assessment']
#     Matched canonical headers: ['Learning Outcomes', 'Deliverables Outcomes', 'Assessments']
#     Successfully extracted data from Table 7 to COMSECT_Syllabus_2024.csv
#
# Processing file: MNTSDEV-SNTSDEV-INTSDEV Course Syllabus 2023 - 2024.docx
#   Found potentially relevant Table 7.
#     Headers in Table 7 (first row): ['Week', 'Topics', 'Learning Activities', 'Learning Outcomes', 'Instructional Materials', 'Deliverables/\nOutcomes', 'Assessment']
#     Matched canonical headers: ['Learning Outcomes', 'Deliverables Outcomes', 'Assessments']
#     Successfully extracted data from Table 7 to MNTSDEV-SNTSDEV-INTSDEV Course Syllabus 2023 - 2024.csv
#
# Processing file: Softdev Syllabus 2023 - 2024 for CS and IT.docx
#   Found potentially relevant Table 7.
#     Headers in Table 7 (first row): ['Week', 'Topics', 'Learning Activities', 'Learning Outcomes', 'Instructional Materials', 'Deliverables/\nOutcomes', 'Assessment']
#     Matched canonical headers: ['Learning Outcomes', 'Deliverables Outcomes', 'Assessments']
#     Successfully extracted data from Table 7 to Softdev Syllabus 2023 - 2024 for CS and IT.csv
#
# Processing file: ITCONCE_SYLLABUS_AY2023-2024 - Revise Oct 2023.docx
#   Found potentially relevant Table 7.
#     Headers in Table 7 (first row): ['Week', 'Topics', 'Learning Activities', 'Learning Outcomes', 'Instructional Materials', 'Deliverables/\nOutcomes', 'Assessment']
#     Matched canonical headers: ['Learning Outcomes', 'Deliverables Outcomes', 'Assessments']
#     Successfully extracted data from Table 7 to ITCONCE_SYLLABUS_AY2023-2024 - Revise Oct 2023.csv
#
# Processing file: INTCOMC_Syllabus 2024-2025.docx
#   Found potentially relevant Table 7.
#     Headers in Table 7 (first row): ['Week', 'Topics', 'Learning Activities', 'Learning Outcomes', 'Instructional Materials', 'Deliverables/ Outcomes', 'Assessment']
#     Matched canonical headers: ['Learning Outcomes', 'Deliverables Outcomes', 'Assessments']
#     Successfully extracted data from Table 7 to INTCOMC_Syllabus 2024-2025.csv
#
# Processing file: USERDES Course Syllabus 1T 2020.docx
#   Found potentially relevant Table 2.
#     Headers in Table 2 (first row): ['W\ne\ne\nk', 'Topics', 'Learning Activities', 'Learning Outcomes\n(At the end of the session, students are expected to:)', 'Instructional Materials', 'Deliverables/\nOutcomes', 'Assessment']
#     Matched canonical headers: ['Learning Outcomes', 'Deliverables Outcomes', 'Assessments']
#     Successfully extracted data from Table 2 to USERDES Course Syllabus 1T 2020.csv
#
# Processing file: PROJMAN _Syllabus_T1 AY 2024-2025.docx
#   Found potentially relevant Table 9.
#     Headers in Table 9 (first row): ['Week', 'Topics', 'Learning Activities', 'Learning Outcomes', 'Instructional Materials', 'Deliverables/ Outcomes', 'Assessment', 'Mode']
#     Matched canonical headers: ['Learning Outcomes', 'Deliverables Outcomes', 'Assessments']
#     Successfully extracted data from Table 9 to PROJMAN _Syllabus_T1 AY 2024-2025.csv
#
# Processing file: WEBPROG_Syllabus_2023_2024.docx
#   Found potentially relevant Table 7.
#     Headers in Table 7 (first row): ['Week', 'Topics', 'Learning Activities', 'Learning Outcomes', 'Instructional Materials', 'Deliverables/\nOutcomes', 'Assessment']
#     Matched canonical headers: ['Learning Outcomes', 'Deliverables Outcomes', 'Assessments']
#     Successfully extracted data from Table 7 to WEBPROG_Syllabus_2023_2024.csv
#
# Processing file: PROGCON_SYLLABUS_2ndTerm_2024_3.0.docx
#   Found potentially relevant Table 7.
#     Headers in Table 7 (first row): ['Week', 'Topics', 'Learning Activities', 'Learning Outcomes', 'Instructional Materials', 'Deliverables/\xa0\nOutcomes', 'Assessment']
#     Matched canonical headers: ['Learning Outcomes', 'Deliverables Outcomes', 'Assessments']
#     Successfully extracted data from Table 7 to PROGCON_SYLLABUS_2ndTerm_2024_3.0.csv
#
# Processing file: MOBPROG Course Syllabus 1T 2024-2025 Revise version.docx
#   Found potentially relevant Table 6.
#     Headers in Table 6 (first row): ['W\ne\ne\nk', 'Topics', 'Learning Activities', 'Learning Outcomes\n(At the end of the session, students are expected to :)', 'Instructional Materials', 'Deliverables/\nOutcomes', 'Assessment']
#     Matched canonical headers: ['Learning Outcomes', 'Deliverables Outcomes', 'Assessments']
#     Successfully extracted data from Table 6 to MOBPROG Course Syllabus 1T 2024-2025 Revise version.csv
#
# Processing file: SCSPROJ - MCSPROJ Course Syllabus AY 2023 - 2024.docx
#   Found potentially relevant Table 7.
#     Headers in Table 7 (first row): ['Week\n#', 'Topics', 'Learning Activities', 'Learning Outcomes', 'Instructional\nMaterials*', 'Deliverables/\nOutcomes', 'Assessment']
#     Matched canonical headers: ['Learning Outcomes', 'Deliverables Outcomes', 'Assessments']
#     Successfully extracted data from Table 7 to SCSPROJ - MCSPROJ Course Syllabus AY 2023 - 2024.csv
#
# Processing file: SCSPROJ - MCSPROJ Course Syllabus AY 2023 - 2024.docx
#   Found potentially relevant Table 8.
#     Headers in Table 8 (first row): ['Week\n#', 'Topics', 'Learning Activities', 'Learning Outcomes', 'Instructional\nMaterials*', 'Deliverables/\nOutcomes', 'Assessment']
#     Matched canonical headers: ['Learning Outcomes', 'Deliverables Outcomes', 'Assessments']
#     Successfully extracted data from Table 8 to SCSPROJ - MCSPROJ Course Syllabus AY 2023 - 2024.csv
#
# Processing file: SCSPROJ - MCSPROJ Course Syllabus AY 2023 - 2024.docx
#   Found potentially relevant Table 9.
#     Headers in Table 9 (first row): ['Week\n#', 'Topics', 'Learning Activities', 'Learning Outcomes', 'Instructional\nMaterials*', 'Deliverables/ Outcomes', 'Assessment']
#     Matched canonical headers: ['Learning Outcomes', 'Deliverables Outcomes', 'Assessments']
#     Successfully extracted data from Table 9 to SCSPROJ - MCSPROJ Course Syllabus AY 2023 - 2024.csv
#
# Processing file: SCSPROJ - MCSPROJ Course Syllabus AY 2023 - 2024.docx
#   Found potentially relevant Table 10.
#     Headers in Table 10 (first row): ['Week\n#', 'Topics', 'Learning Activities', 'Learning \nOutcomes', 'Instructional\nMaterials*', 'Deliverables/\nOutcomes', 'Assessment']
#     Matched canonical headers: ['Learning Outcomes', 'Deliverables Outcomes', 'Assessments']
#     Successfully extracted data from Table 10 to SCSPROJ - MCSPROJ Course Syllabus AY 2023 - 2024.csv
#
# Processing file: SOFTDEV_Syllabus_T1_AY_ 2024_2025_for_CS_and _T.docx
#   Found potentially relevant Table 9.
#     Headers in Table 9 (first row): ['Week', 'Topics', 'Learning Activities', 'Learning Outcomes', 'Instructional Materials', 'Deliverables/\nOutcomes', 'Assessment']
#     Matched canonical headers: ['Learning Outcomes', 'Deliverables Outcomes', 'Assessments']
#     Successfully extracted data from Table 9 to SOFTDEV_Syllabus_T1_AY_ 2024_2025_for_CS_and _T.csv
#
# Processing file: MODESIM_Syllabus_2024.docx
#   Found potentially relevant Table 6.
#     Headers in Table 6 (first row): ['Week', 'Topics', 'Learning Activities', 'Learning Outcomes', 'CO / CLO\nAligned To', 'Instructional Materials', 'Deliverables/\nOutcomes', 'Assessment']
#     Matched canonical headers: ['Learning Outcomes', 'Deliverables Outcomes', 'Assessments']
#     Successfully extracted data from Table 6 to MODESIM_Syllabus_2024.csv
#
# Processing file: SCSPROJ Course Syllabus AY2024-2025 for CS.docx
#   Found potentially relevant Table 10.
#     Headers in Table 10 (first row): ['Week #', 'Topics', 'Learning Activities', 'Learning Outcomes (LO) / Learner and Learning Outcomes (LLO)', 'CO / CLO \nAligned to', 'Instructional Materials*', 'Deliverables\n/ Outcomes/Rubrics', 'Deliverables\n/ Outcomes/Rubrics', 'Deliverables\n/ Outcomes/Rubrics', 'Assessment']
#     Matched canonical headers: ['Learning Outcomes', 'Deliverables Outcomes', 'Assessments']
#     Successfully extracted data from Table 10 to SCSPROJ Course Syllabus AY2024-2025 for CS.csv
#
# Processing file: MOBAPPL  Syllabus T2 A.Y. 2024-2025 Revise version.docx
#   Found potentially relevant Table 6.
#     Headers in Table 6 (first row): ['Week', 'Topics', 'Learning Activities', 'Learning Outcome', 'Instructional Materials', 'Deliverable / Outcomes', 'Assessment']
#     Matched canonical headers: ['Learning Outcomes', 'Assessments']
#     Successfully extracted data from Table 6 to MOBAPPL  Syllabus T2 A.Y. 2024-2025 Revise version.csv
#
# Processing file: Course Syllabus PHYSICS2 Natural Physics 2 for IT.docx
#   Found potentially relevant Table 6.
#     Headers in Table 6 (first row): ['Week', 'Topics', 'Learning Activities', 'Learning Outcomes (LO) / Learner and Learning Outcomes (LLO)', 'CO Aligned to', 'Instructional Materials', 'Deliverables/ Outcomes', 'Assessment']
#     Matched canonical headers: ['Learning Outcomes', 'Deliverables Outcomes', 'Assessments']
#     Successfully extracted data from Table 6 to Course Syllabus PHYSICS2 Natural Physics 2 for IT.csv
#
# Processing file: COMPORG_SYLLABUS_AY2024_2025.docx
#   Found potentially relevant Table 9.
#     Headers in Table 9 (first row): ['Week', 'Topics', 'Learning Activities', 'Learning Outcomes', 'Instructional Materials', 'Deliverables/\nOutcomes', 'Assessment']
#     Matched canonical headers: ['Learning Outcomes', 'Deliverables Outcomes', 'Assessments']
#     Successfully extracted data from Table 9 to COMPORG_SYLLABUS_AY2024_2025.csv
#
# Processing file: COMPORG_SYLLABUS_AY2024_2025.docx
#   Found potentially relevant Table 10.
#     Headers in Table 10 (first row): ['Week', 'Topics', 'Learning Activities', 'Learning Outcomes', 'Learning Outcomes', 'Instructional Materials', 'Deliverables/\nOutcomes', 'Assessment']
#     Matched canonical headers: ['Learning Outcomes', 'Deliverables Outcomes', 'Assessments']
#     Successfully extracted data from Table 10 to COMPORG_SYLLABUS_AY2024_2025.csv
#
# Processing file: ENTJAVA (Using C# .NET) Course Syllabus 2023-2024.docx
#   Found potentially relevant Table 8.
#     Headers in Table 8 (first row): ['Week', 'Topics', 'Learning Activities', 'Learning Outcomes', 'Instructional Materials', 'Deliverables/\nOutcomes', 'Assessment']
#     Matched canonical headers: ['Learning Outcomes', 'Deliverables Outcomes', 'Assessments']
#     Successfully extracted data from Table 8 to ENTJAVA (Using C# .NET) Course Syllabus 2023-2024.csv
#
# Processing file: INPROLA Syllabus T1 A.Y. 2024-2025 Revise version.docx
#   Found potentially relevant Table 9.
#     Headers in Table 9 (first row): ['Week', 'Topics', 'Learning Activities', 'Learning Outcomes', 'Instructional Materials', 'Assessment']
#     Matched canonical headers: ['Learning Outcomes', 'Assessments']
#     Successfully extracted data from Table 9 to INPROLA Syllabus T1 A.Y. 2024-2025 Revise version.csv
#
# Processing file: DATAMA2_SYLLABUS_2nd_Term_2024_version3.0.docx
#   Found potentially relevant Table 6.
#     Headers in Table 6 (first row): ['Week', 'Topics', 'Learning Activities', 'Learning Outcomes (LO) / \nLearner and Learning Outcomes (LLO)', 'CO\nAligned to', 'Instructional Materials', 'Deliverables/\nOutcomes', 'Assessment']
#     Matched canonical headers: ['Learning Outcomes', 'Deliverables Outcomes', 'Assessments']
#     Successfully extracted data from Table 6 to DATAMA2_SYLLABUS_2nd_Term_2024_version3.0.csv
#
# Processing file: DATAMA1_SYLLABUS_2024_1st_term_Version.docx
#   Found potentially relevant Table 7.
#     Headers in Table 7 (first row): ['Week', 'Topics', 'Learning Activities', 'Learning Outcomes', 'Instructional Materials', 'Deliverables/\nOutcomes', 'Assessment']
#     Matched canonical headers: ['Learning Outcomes', 'Deliverables Outcomes', 'Assessments']
#     Successfully extracted data from Table 7 to DATAMA1_SYLLABUS_2024_1st_term_Version.csv
#
# Processing file: SSYADD1-MSYADD1_Syllabus_T1 AY 2024-2025.docx
#   Found potentially relevant Table 8.
#     Headers in Table 8 (first row): ['Week', 'Topics', 'Learning Activities', 'Learning Outcomes', 'Instructional Materials', 'Deliverables/\nOutcomes', 'Assessment', 'Mode']
#     Matched canonical headers: ['Learning Outcomes', 'Deliverables Outcomes', 'Assessments']
#     Successfully extracted data from Table 8 to SSYADD1-MSYADD1_Syllabus_T1 AY 2024-2025.csv
#
# Processing complete.

# %%
import pandas as pd
import glob
import os

# Change the output folder for the combined CSV
output_folder = "/content/combined_csv"
combined_csv_filename = "combined_syllabi_data.csv"
combined_csv_filepath = os.path.join(output_folder, combined_csv_filename)

# Create the output directory if it doesn't exist
os.makedirs(output_folder, exist_ok=True)

# Get a list of all CSV files in the source folder (where individual CSVs are saved)
source_csv_folder = "/content/csv_outputs"
csv_files = glob.glob(os.path.join(source_csv_folder, "*.csv"))

# Check if there are any CSV files to combine
if not csv_files:
    print(f"No CSV files found in {source_csv_folder} to combine.")
else:
    # Create an empty list to store DataFrames
    df_list = []

    # Read each CSV file into a DataFrame and append to the list
    for file in csv_files:
        try:
            df = pd.read_csv(file)
            df_list.append(df)
            print(f"Read {os.path.basename(file)}")
        except Exception as e:
            print(f"Error reading {os.path.basename(file)}: {e}")

    # Concatenate all DataFrames into a single DataFrame
    if df_list:
        combined_df = pd.concat(df_list, ignore_index=True)

        # Save the combined DataFrame to a new CSV file in the specified output folder
        combined_df.to_csv(combined_csv_filepath, index=False)

        print(f"\nSuccessfully combined {len(csv_files)} CSV files into {combined_csv_filename}")
        print(f"Combined CSV saved to: {combined_csv_filepath}")
    else:
        print("No DataFrames were successfully read to combine.")
# Out:
# Read CLDSRV2_Syllabus_2024.csv
# Read MOBAPPL  Syllabus T2 A.Y. 2024-2025 Revise version.csv
# Read CRISKMA Syllabus AY 2024 - 2025.csv
# Read DESALGO_Syllabus_2024.csv
# Read DATAMA1_SYLLABUS_Ver3.0_2023.csv
# Read USERDES Course Syllabus 1T 2020.csv
# Read MNSYSIT Course Syllabus AY 2024-2025.csv
# Read COMPORG_SYLLABUS_AY2024_2025.csv
# Read DATAMA2_SYLLABUS_2nd_Term_2024_version3.0.csv
# Read WEBPSEC_Syllabus_2024.csv
# Read Course Syllabus PHYSICS1 Natural Physics 1 for IT.csv
# Read SOFTDEV_Syllabus_T1_AY_ 2024_2025_for_CS_and _T.csv
# Read MNSYSIT Salesforce_AY 2023-2024 v2.csv
# Read PROJMAN _Syllabus_T1 AY 2024-2025.csv
# Read OPESYST_SYLLABUS_AY2024-2025.csv
# Read INPROLA Syllabus 2ndTerm_2024ver3.0.csv
# Read COMSEC2_Syllabus_2024.csv
# Read SCSPROJ - MCSPROJ Course Syllabus AY 2023 - 2024.csv
# Read MOBPROG Course Syllabus 1T 2022 - Revise Oct 2023.csv
# Read PROGCON_SYLLABUS_2ndTerm_2024_3.0.csv
# Read THESIS2 2023 Syllabus  T1 AY 2024 2025.csv
# Read MODESIM_Syllabus_2024.csv
# Read COMSEC3_Syllabus_2024 - 2025.csv
# Read INFOSEC_Syllabus_2023.csv
# Read Course Syllabus PHYSICS2 Natural Physics 2 for IT.csv
# Read MCSPROJ Course Syllabus AY2024-2025 for IT.csv
# Read DASTRUC_Syllabus T1 AY 2024-2025 Revise version.csv
# Read INPROLA Syllabus T1 A.Y. 2024-2025 Revise version.csv
# Read COMSECT_Syllabus_2024.csv
# Read NETDESM_2024.csv
# Read PROJMAN AY 2023_2024 Syllabus.csv
# Read WEBPROG_Syllabus_2023_2024.csv
# Read Softdev Syllabus 2023 - 2024 for CS and IT.csv
# Read SSYADD1-MSYADD1_Syllabus_2023.csv
# Read QUALITY_SYLLABUS_2023 for CS.csv
# Read PROGCON_SYLLABUS_2024_1stTerm_version.csv
# Read INPROLA Syllabus Revision T1 A.Y. 2023 Revise Oct 2023.csv
# Read ENTJAVA (Using C# .NET) Course Syllabus 2023-2024.csv
# Read DATAMA1_SYLLABUS_2024_1st_term_Version.csv
# Read MNTSDEV-SNTSDEV-INTSDEV Course Syllabus 2023 - 2024.csv
# Read CLDSRV2_Syllabus 2023_2024.csv
# Read PROGCON Syllabus Revision  T1 A.Y. 2023-2024 Revise Oct 2023.csv
# Read INTSDEV_Syllabus_2023-2024.csv
# Read SCSPROJ Course Syllabus AY2024-2025 for CS.csv
# Read MOBPROG Course Syllabus 1T 2024-2025 Revise version.csv
# Read MNSYSIT Salesforce_T1 AY 2024-2025 for upload.csv
# Read AUTOMAT_SYLLABUS_2ndTerm_2024_ver3.0.csv
# Read MNTSDEV-SNTSDEV-INTSDEV Course Syllabus AY 2024 - 2025 v2.csv
# Read CSPROJ2 Course Syllabus AY2024-2025 (KRC)v.03.csv
# Read ITCONCE_SYLLABUS_AY2023-2024 - Revise Oct 2023.csv
# Read SSYADD1-MSYADD1_Syllabus_T1 AY 2024-2025.csv
# Read INTCOMC_Syllabus 2024-2025.csv
# Read ICTSRV1_Syllabus_2024.csv
# Read DATAMA2_SYLLABUS_1st_Term_2024_version.csv
# Read QUALITY_SYLLABUS_AY_2023_2024 for IT.csv
# Read CLDCOMP_Syllabus 2023-2024.csv
# Read INFOSEC_Syllabus_T1_AY_2024_2025.csv
#
# Successfully combined 57 CSV files into combined_syllabi_data.csv
# Combined CSV saved to: /content/combined_csv/combined_syllabi_data.csv
